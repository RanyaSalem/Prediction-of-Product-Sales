# %% [markdown]
# <a href="https://colab.research.google.com/github/RanyaSalem/Prediction-of-Product-Sales/blob/main/sales_predictions_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading Data

# %%
import pandas as pd
df = pd.read_csv('/content/sales_predictions_2023.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ** 1) How many rows and columns?

# %%
rows, cols = df.shape
rows,cols
# Out:
# (8523, 12)

# %% [markdown]
# ** 2) What are the datatypes of each variable?

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ** 3)Are there duplicates? If so, drop any duplicates.

# %%
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# np.int64(0)

# %% [markdown]
# 4) Identify missing values.

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# 5) Address the missing values by using a placeholder value.:

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna('Missing')
df['Item_Weight'] = df['Item_Weight'].fillna(0)
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium     2793
# Missing    2410
# Small      2388
# High        932
# Name: count, dtype: int64

# %%
df['Item_Weight'].value_counts()
# Out:
# Item_Weight
# 0.000     1463
# 12.150      86
# 17.600      82
# 13.650      77
# 11.800      76
#           ...
# 5.210        2
# 9.420        1
# 7.685        1
# 5.400        1
# 6.520        1
# Name: count, Length: 416, dtype: int64

# %% [markdown]
# 6) Confirm that there are no missing values after addressing them.

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# 7) Find and fix any inconsistent categories of data.

# %%
df['Item_Fat_Content'].value_counts()
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({
    'LF': 'Low Fat',
    'low fat': 'Low Fat',
    'reg': 'Regular'})
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# 8) For any numerical columns, obtain the summary statistics.

# %%
statistics = df.describe().loc[['min', 'max', 'mean']]
display(statistics)
# Out:
#       Item_Weight  Item_Visibility    Item_MRP  Outlet_Establishment_Year  \
# min       0.00000         0.000000   31.290000                1985.000000
# max      21.35000         0.328391  266.888400                2009.000000
# mean     10.65059         0.066132  140.992782                1997.831867
#
#       Item_Outlet_Sales
# min           33.290000
# max        13086.964800
# mean        2181.288914
