# %% [markdown]
# <a href="https://colab.research.google.com/github/RanyaSalem/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales
# **Author:** Rania Salem
#
# ## Project Overview
# This project aims to predict sales for food items across different stores to help retailers understand the main drivers of sales.

# %% [markdown]
# ## 1. Data Loading & Cleaning
#
# *   List item
# *   List item

# %% [markdown]
# ## 2. Load and Inspect Data
# *   List item
# *   List item

# %% [markdown]
# ## 3. Clean Data
#
# *   List item
# *   List item

# %% [markdown]
# ## 4. Exploratory Data Analysis
#
# *   List item
# *   List item

# %% [markdown]
# ## 5. Feature Inspection
#
# *   List item
# *   List item
